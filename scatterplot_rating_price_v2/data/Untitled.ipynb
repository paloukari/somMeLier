# %%
import pandas as pd

# %%
df = pd.read_csv('result.csv')

# %%
# df = df.rename(index=str, columns={"pice": "price"})
# df['price'] = df['price'].astype(float)
# df = df[df['price']!= '#VALUE!']
# df = df[df['price']!= '0.00']
# df.sort_values('price')
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             0
# 1           1             1
# 2           2             2
# 3           3             3
# 4           4             4
#
#                                                  url             winery  \
# 0  https://www.vivino.com/tarapaca-sarmientos-de-...           Tarapacá
# 1  https://www.vivino.com/marques-de-toledo-blanc...  Marques de Toledo
# 2  https://www.vivino.com/paul-mas-vermentino/w/2...           Paul Mas
# 3  https://www.vivino.com/villard-grand-vin-le-pi...            Villard
# 4  https://www.vivino.com/quinta-da-neve-pinot-no...     Quinta da Neve
#
#                                           name       types             region  \
# 0  Sarmientos de Tarapacá Sauvignon Blanc 2017  White wine     Central Valley
# 1                                 Verdejo 2016  White wine          La Mancha
# 2                              Vermentino 2016  White wine          Pays d'Oc
# ...

# %%
df.to_csv('result.csv')
